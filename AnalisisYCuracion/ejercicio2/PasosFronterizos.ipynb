# %% [markdown]
# <h1>Pasos Fronterizos</h1>

# %% [markdown]
# <h2>Ejercicio</h2>
#
# * Graficar histograma de cantidad de pasos por provincia

# %% [markdown]
# <h3>1 Importando pandas, matplotlib, seaborn</h3>

# %%
import pandas
import seaborn
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>2 Cargando datos</h3>

# %%
pasos_fronterizos = pandas.read_json("pasos.json")
pasos_fronterizos
# Out:
#                                location                             name  \
# 0             [-54.832543, -68.3712885]       SAN SEBASTIAN  ( USHUAIA )
# 1            [-54.8249379, -68.3258626]          AERO PUBLICO DE USHUAIA
# 2            [-54.8096728, -68.3114748]      PUERTO USHUAIA (PREFECTURA)
# 3            [-54.8019121, -68.3029511]                   PUERTO USHUAIA
# 4            [-51.6896359, -72.2993574]        PASO LAURITA CASAS VIEJAS
# 5            [-51.5866042, -72.3649779]                     PASO DOROTEA
# 6            [-51.2544488, -72.2652242]           PASO RIO DON GUILLERMO
# 7            [-53.3229179, -68.6063227]               PASO SAN SEBASTIAN
# 8              [-53.78438, -67.7173342]              TERMINAL RIO GRANDE
# 9            [-53.7860374, -67.7002243]                PUERTO RIO GRANDE
# 10           [-52.2527012, -69.8852885]                     MONTE AYMOND
# 11           [-52.1304141, -69.5198778]              INTEGRACION AUSTRAL
# ...

# %% [markdown]
# <h3>3 Grafica</h3>

# %%
# Configuración del grafico
plt.figure(figsize=(20,10))
plt.title('Histograma de cantidad por provincia')
plt.xlabel('Cantidad de pasos');
plt.ylabel('Porcentaje')
plt.rcParams.update({'font.size': 22})

# Optención de data frame con datos de cantidad de pasos por provincia
cantidad_de_pasos_por_provincia_data_frame = pasos_fronterizos.province.value_counts().to_frame()
#cantidad_de_pasos_por_provincia_data_frame

# Grafico con seaborn
seaborn.distplot(cantidad_de_pasos_por_provincia_data_frame)
